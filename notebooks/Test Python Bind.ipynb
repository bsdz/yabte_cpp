# %%
import sys

sys.path.append("/home/blair/projects/yabte_cpp/build/Debug/pybind")

import pandas as pd
import pyarrow as pa
import yabte
import yabte.backtest as ybt
import yabte_cpp_backtest as ybt_cpp
from yabte.tests._helpers import generate_nasdaq_dataset
from yabte.utilities.strategy_helpers import crossover
from yabte.utilities.plot.plotly.strategy_runner import plot_strategy_runner_result

ybt_cpp.__version__, yabte.__version__
# Out:
# ('"Tue Apr  9 15:01:03 2024"', '0.4.0')

# %%
class SMAXO(ybt_cpp.Strategy):
    def __init__(self):
        ybt_cpp.Strategy.__init__(self)

    def clone(self):
        cloned = SMAXO.__new__(SMAXO)
        ybt_cpp.Strategy.__init__(cloned, self)
        cloned.__dict__.update(self.__dict__)
        return cloned

    def extend_data(self, data):
        # enhance data with simple moving averages

        df = data.to_pandas()

        p = self.params
        days_short = p["days_short"]
        days_long = p["days_long"]

        close_sma_short = (
            df.loc[:, (slice(None), "Close")]
            .rolling(days_short)
            .mean()
            .rename({"Close": "CloseSMAShort"}, axis=1, level=1)
        )
        close_sma_long = (
            df.loc[:, (slice(None), "Close")]
            .rolling(days_long)
            .mean()
            .rename({"Close": "CloseSMALong"}, axis=1, level=1)
        )
        new_df = pd.concat([close_sma_short, close_sma_long], axis=1).sort_index(axis=1)

        return pa.Table.from_pandas(new_df)

    def init(self): ...

    def on_close(self):
        # create some orders

        p = self.params
        days_long = p["days_long"]

        if (L := len(self.data)) < days_long + 1:
            return

        # for symbol in ["GOOG", "MSFT"]:
        for symbol in ["GOOG"]:
            key_long = f"('{symbol}', 'CloseSMALong')"
            key_short = f"('{symbol}', 'CloseSMAShort')"

            close_sma_short = self.data[key_short].slice(L - 2, 2).to_pandas()
            close_sma_long = self.data[key_long].slice(L - 2, 2).to_pandas()

            if crossover(close_sma_short, close_sma_long):
                self.orders.append(ybt_cpp.SimpleOrder(asset_name=symbol, size=-100))
            elif crossover(close_sma_long, close_sma_short):
                self.orders.append(ybt_cpp.SimpleOrder(asset_name=symbol, size=100))
                
# load some data
assets_py, df_combined = generate_nasdaq_dataset()

# convert to arrow table
table_ar = pa.Table.from_pandas(df_combined)

# recreate cpp assets from python assets
assets = [ybt_cpp.OHLCAsset(name=a.name) for a in assets_py]

# create a strategy
strategies = [SMAXO()]

# create a book with 100000 cash
books = [ybt_cpp.Book(name="Main", cash=100000)]

# run the strategy
sr1 = ybt_cpp.StrategyRunner(table_ar, assets, strategies, books)
srr1 = sr1.run(dict(days_short=10, days_long=20))
# Out:
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# I20240410 21:46:11.492758 893111 StrategyRunner.cpp:40] Running strategy runner
# I20240410 21:46:11.503059 893111 StrategyRunner.cpp:77] Extending data for strategy
# I20240410 21:46:11.514972 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:11.540762 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:11.576054 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:11.610029 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:11.631928 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:11.644712 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:11.712435 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:11.729684 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:11.777037 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:11.835713 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:11.850883 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:11.926810 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:11.945535 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:11.972088 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.040740 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.047086 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.102099 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.109903 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.147734 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.214504 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.291627 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.313701 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.318974 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.327780 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.363490 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.382861 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.441429 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.448169 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.525794 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.528975 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.552737 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.608217 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.712299 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.715837 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.719338 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.732728 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.773164 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.795807 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.832567 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.866958 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.962757 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:12.989658 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.056444 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.077399 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.083034 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.086536 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.094079 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.107803 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.168303 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.185359 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.333178 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.370443 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.425825 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.449092 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.466261 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.522750 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.542119 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.580516 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.612874 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.689476 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.706106 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.725001 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.751331 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.771677 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.801318 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.869071 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.878430 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.883940 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.893327 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.922660 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.950277 893111 Order.cpp:69] SimpleOrder::apply()
# I20240410 21:46:13.977706 893111 StrategyRunner.cpp:150] Finished running strategy runner

# %%
srr1.book_history.rename_columns(["Date", "('Main', 'cash')", "('Main', 'mtm')", "('Main', 'total')"])
# Out:
# pyarrow.Table
# Date: timestamp[ns] not null
# ('Main', 'cash'): double not null
# ('Main', 'mtm'): double not null
# ('Main', 'total'): double not null
# ----
# Date: [[2018-01-02 00:00:00.000000000,2018-01-03 00:00:00.000000000,2018-01-04 00:00:00.000000000,2018-01-05 00:00:00.000000000,2018-01-08 00:00:00.000000000,...,2022-12-23 00:00:00.000000000,2022-12-27 00:00:00.000000000,2022-12-28 00:00:00.000000000,2022-12-29 00:00:00.000000000,2022-12-30 00:00:00.000000000]]
# ('Main', 'cash'): [[100000,100000,100000,100000,100000,...,95169,95169,95169,95169,95169]]
# ('Main', 'mtm'): [[0,0,0,0,0,...,8981,8793,8646,8895,8873]]
# ('Main', 'total'): [[100000,100000,100000,100000,100000,...,104150,103962,103815,104064,104042]]

# %%
srr1.book_history.to_pandas()
# Out:
#      ('Main', 'ts')  ('Main', 'cash')  ('Main', 'mtm')  ('Main', 'total')
# 0        2018-01-02          100000.0              0.0           100000.0
# 1        2018-01-03          100000.0              0.0           100000.0
# 2        2018-01-04          100000.0              0.0           100000.0
# 3        2018-01-05          100000.0              0.0           100000.0
# 4        2018-01-08          100000.0              0.0           100000.0
# ...             ...               ...              ...                ...
# 1254     2022-12-23           95169.0           8981.0           104150.0
# 1255     2022-12-27           95169.0           8793.0           103962.0
# 1256     2022-12-28           95169.0           8646.0           103815.0
# 1257     2022-12-29           95169.0           8895.0           104064.0
# 1258     2022-12-30           95169.0           8873.0           104042.0
#
# [1259 rows x 4 columns]

# %%
srr1.book_history#.to_pandas().loc[:, "('Main', 'mtm')"].plot()
# Out:
# pyarrow.Table
# ('Main', 'ts'): timestamp[ns] not null
# ('Main', 'cash'): double not null
# ('Main', 'mtm'): double not null
# ('Main', 'total'): double not null
# ----
# ('Main', 'ts'): [[2018-01-02 00:00:00.000000000,2018-01-03 00:00:00.000000000,2018-01-04 00:00:00.000000000,2018-01-05 00:00:00.000000000,2018-01-08 00:00:00.000000000,...,2022-12-23 00:00:00.000000000,2022-12-27 00:00:00.000000000,2022-12-28 00:00:00.000000000,2022-12-29 00:00:00.000000000,2022-12-30 00:00:00.000000000]]
# ('Main', 'cash'): [[100000,100000,100000,100000,100000,...,95169,95169,95169,95169,95169]]
# ('Main', 'mtm'): [[0,0,0,0,0,...,8981,8793,8646,8895,8873]]
# ('Main', 'total'): [[100000,100000,100000,100000,100000,...,104150,103962,103815,104064,104042]]

# %%
srr1.books[0].transactions
# Out:
# [<yabte_backtest_cpp.Trade ts=2018-02-08 00:00:00.000000000, total=-5148, desc=buy GOOG, quantity=100, price=51.48, asset_name=GOOG, >,
#  <yabte_backtest_cpp.Trade ts=2018
asset_name=GOOG, >,
#  <yabte_backtest_cpp.Trade ts=2022-08-08 00:00:00.000000000, total=11935, desc=sell GOOG, quantity=-100, price=119.35, asset_name=GOOG, >,
#  <yabte_backtest_cpp.Trade ts=2022-08-29 00:00:00.000000000, total=-11088, desc=buy GOOG, quantity=100, price=110.88, asset_name=GOOG, >,
#  <yabte_backtest_cpp.Trade ts=2022-10-17 00:00:00.000000000, total=10064, desc=sell GOOG, quantity=-100, price=100.64, asset_name=GOOG, >,
#  <yabte_backtest_cpp.Trade ts=2022-10-21 00:00:00.000000000, total=-9993, desc=buy GOOG, quantity=100, price=99.93, asset_name=GOOG, >,
#  <yabte_backtest_cpp.Trade ts=2022-10-25 00:00:00.000000000, total=10406, desc=sell GOOG, quantity=-100, price=104.06, asset_name=GOOG, >,
#  <yabte_backtest_cpp.Trade ts=2022-10-31 00:00:00.000000000, total=-9536, desc=buy GOOG, quantity=100, price=95.36, asset_name=GOOG, >,
#  <yabte_backtest_cpp.Trade ts=2022-11-21 00:00:00.000000000, total=9719, desc=sell GOOG, quantity=-100, price=97.19, asset_name=GOOG, >,
#  <yabte_backtest_cpp.Trade ts=2022-12-12 00:00:00.000000000, total=-9289, desc=buy GOOG, quantity=100, price=92.89, asset_name=GOOG, >]

# %%
srr1.books[0].history
# Out:
# pyarrow.Table
# ts: timestamp[ns] not null
# cash: double not null
# mtm: double not null
# total: double not null
# ----
# ts: [[2018-01-02 00:00:00.000000000,2018-01-03 00:00:00.000000000,2018-01-04 00:00:00.000000000,2018-01-05 00:00:00.000000000,2018-01-08 00:00:00.000000000,...,2022-12-23 00:00:00.000000000,2022-12-27 00:00:00.000000000,2022-12-28 00:00:00.000000000,2022-12-29 00:00:00.000000000,2022-12-30 00:00:00.000000000]]
# cash: [[100000,100000,100000,100000,100000,...,95169,95169,95169,95169,95169]]
# mtm: [[0,0,0,0,0,...,8981,8793,8646,8895,8873]]
# total: [[100000,100000,100000,100000,100000,...,104150,103962,103815,104064,104042]]

# %%
class SMAXO(ybt.Strategy):
    def init(self):
        # enhance data with simple moving averages

        p = self.params
        days_short = p.get("days_short", 10)
        days_long = p.get("days_long", 20)

        close_sma_short = (
            self.data.loc[:, (slice(None), "Close")]
            .rolling(days_short)
            .mean()
            .rename({"Close": "CloseSMAShort"}, axis=1, level=1)
        )
        close_sma_long = (
            self.data.loc[:, (slice(None), "Close")]
            .rolling(days_long)
            .mean()
            .rename({"Close": "CloseSMALong"}, axis=1, level=1)
        )
        self.data = pd.concat(
            [self.data, close_sma_short, close_sma_long], axis=1
        ).sort_index(axis=1)

    def on_close(self):
        # create some orders

        # for symbol in ["GOOG", "MSFT"]:
        for symbol in ["GOOG"]:
            df = self.data[symbol]
            ix_2d = df.index[-2:]
            data = df.loc[ix_2d, ("CloseSMAShort", "CloseSMALong")].dropna()
            if len(data) == 2:
                if crossover(data.CloseSMAShort, data.CloseSMALong):
                    self.orders.append(ybt.SimpleOrder(asset_name=symbol, size=-100))
                elif crossover(data.CloseSMALong, data.CloseSMAShort):
                    self.orders.append(ybt.SimpleOrder(asset_name=symbol, size=100))


# load some data
assets, df_combined = generate_nasdaq_dataset()

# create a book with 100000 cash
book = ybt.Book(name="Main", cash="100000")

# run our strategy
sr2 = ybt.StrategyRunner(
    data=df_combined,
    assets=assets,
    strategies=[SMAXO()],
    books=[book],
)
srr2 = sr2.run(dict(days_short=10, days_long=20))

# see the trades or book history
th = srr2.transaction_history
bch = srr2.book_history.loc[:, (slice(None), "cash")]

# plot the trades against book value
#plot_strategy_runner_result(srr2, sr2)

# %%
srr2.books[0].transactions
# Out:
# [Trade(ts=Timestamp('2018-02-08 00:00:00'), total=Decimal('-5148.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('51.48'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2018-02-28 00:00:00'), total=Decimal('5577.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('55.77'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2018-03-26 00:00:00'), total=Decimal('-5160.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('51.60'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2018-04-19 00:00:00'), total=Decimal('5406.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('54.06'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2018-05-04 00:00:00'), total=Decimal('-5164.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('51.64'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2018-05-14 00:00:00'), total=Decimal('5525.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('55.25'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2018-07-03 00:00:00'), total=Decimal('-5590.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('55.90'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2018-07-16 00:00:00'), total=Decimal('5926.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('59.26'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2018-08-20 00:00:00'), total=Decimal('-6014.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('60.14'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2018-10-02 00:00:00'), total=Decimal('5991.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('59.91'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2018-10-11 00:00:00'), total=Decimal('-5437.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('54.37'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2018-12-06 00:00:00'), total=Decimal('5255.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('52.55'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2018-12-19 00:00:00'), total=Decimal('-5175.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('51.75'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2019-01-09 00:00:00'), total=Decimal('5373.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('53.73'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2019-03-01 00:00:00'), total=Decimal('-5669.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('56.69'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2019-03-05 00:00:00'), total=Decimal('5790.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('57.90'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2019-04-08 00:00:00'), total=Decimal('-6021.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('60.21'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2019-04-11 00:00:00'), total=Decimal('6020.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('60.20'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2019-05-08 00:00:00'), total=Decimal('-5865.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('58.65'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2019-06-24 00:00:00'), total=Decimal('5583.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('55.83'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2019-08-16 00:00:00'), total=Decimal('-5886.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('58.86'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2019-08-30 00:00:00'), total=Decimal('5956.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('59.56'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2019-09-04 00:00:00'), total=Decimal('-5886.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('58.86'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2019-09-10 00:00:00'), total=Decimal('6011.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('60.11'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2019-10-04 00:00:00'), total=Decimal('-6002.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('60.02'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2019-10-18 00:00:00'), total=Decimal('6250.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('62.50'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2019-12-04 00:00:00'), total=Decimal('-6577.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('65.77'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2019-12-09 00:00:00'), total=Decimal('6743.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('67.43'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2020-02-10 00:00:00'), total=Decimal('-7460.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('74.60'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2020-02-11 00:00:00'), total=Decimal('7588.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('75.88'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2020-02-28 00:00:00'), total=Decimal('-6530.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('65.30'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2020-04-08 00:00:00'), total=Decimal('6018.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('60.18'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2020-06-25 00:00:00'), total=Decimal('-7157.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('71.57'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2020-06-26 00:00:00'), total=Decimal('6964.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('69.64'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2020-06-29 00:00:00'), total=Decimal('-6857.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('68.57'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2020-07-08 00:00:00'), total=Decimal('7479.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('74.79'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2020-08-05 00:00:00'), total=Decimal('-7365.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('73.65'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2020-08-20 00:00:00'), total=Decimal('7810.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('78.10'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2020-09-16 00:00:00'), total=Decimal('-7705.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('77.05'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2020-10-12 00:00:00'), total=Decimal('7816.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('78.16'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2020-12-21 00:00:00'), total=Decimal('-8600.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('86.00'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2021-01-11 00:00:00'), total=Decimal('8887.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('88.87'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2021-03-04 00:00:00'), total=Decimal('-10274.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('102.74'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2021-03-18 00:00:00'), total=Decimal('10273.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('102.73'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2021-03-22 00:00:00'), total=Decimal('-10210.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('102.10'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2021-03-23 00:00:00'), total=Decimal('10279.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('102.79'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2021-03-26 00:00:00'), total=Decimal('-10163.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('101.63'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2021-04-06 00:00:00'), total=Decimal('11131.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('111.31'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2021-05-18 00:00:00'), total=Decimal('-11616.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('116.16'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2021-05-28 00:00:00'), total=Decimal('12090.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('120.90'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2021-09-21 00:00:00'), total=Decimal('-13986.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('139.86'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2021-10-19 00:00:00'), total=Decimal('14360.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('143.60'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2021-12-01 00:00:00'), total=Decimal('-14400.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('144.00'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2021-12-17 00:00:00'), total=Decimal('14312.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('143.12'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2021-12-30 00:00:00'), total=Decimal('-14641.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('146.41'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2022-02-09 00:00:00'), total=Decimal('14128.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('141.28'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2022-02-23 00:00:00'), total=Decimal('-12963.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('129.63'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2022-03-22 00:00:00'), total=Decimal('13900.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('139.00'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2022-04-13 00:00:00'), total=Decimal('-12955.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('129.55'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2022-06-09 00:00:00'), total=Decimal('11661.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('116.61'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2022-06-22 00:00:00'), total=Decimal('-11225.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('112.25'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2022-07-06 00:00:00'), total=Decimal('11430.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('114.30'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2022-07-25 00:00:00'), total=Decimal('-10880.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('108.80'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2022-08-08 00:00:00'), total=Decimal('11935.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('119.35'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2022-08-29 00:00:00'), total=Decimal('-11088.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('110.88'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2022-10-17 00:00:00'), total=Decimal('10064.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('100.64'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2022-10-21 00:00:00'), total=Decimal('-9993.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('99.93'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2022-10-25 00:00:00'), total=Decimal('10406.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('104.06'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2022-10-31 00:00:00'), total=Decimal('-9536.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('95.36'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2022-11-21 00:00:00'), total=Decimal('9719.0000'), desc='sell GOOG', quantity=Decimal('-100.00'), price=Decimal('97.19'), asset_name='GOOG', order_label=None),
#  Trade(ts=Timestamp('2022-12-12 00:00:00'), total=Decimal('-9289.0000'), desc='buy GOOG', quantity=Decimal('100.00'), price=Decimal('92.89'), asset_name='GOOG', order_label=None)]

# %%
srr2.book_history#.loc[:, (slice(None), "mtm")].plot()
# Out:
#                 Main
#                 cash     mtm     total
# ts
# 2018-01-02  100000.0     0.0  100000.0
# 2018-01-03  100000.0     0.0  100000.0
# 2018-01-04  100000.0     0.0  100000.0
# 2018-01-05  100000.0     0.0  100000.0
# 2018-01-08  100000.0     0.0  100000.0
# ...              ...     ...       ...
# 2022-12-23   95169.0  8981.0  104150.0
# 2022-12-27   95169.0  8793.0  103962.0
# 2022-12-28   95169.0  8646.0  103815.0
# 2022-12-29   95169.0  8895.0  104064.0
# 2022-12-30   95169.0  8873.0  104042.0
#
# [1259 rows x 3 columns]

# %%
bch
# Out:
#                 Main
#                 cash
# ts
# 2018-01-02  100000.0
# 2018-01-03  100000.0
# 2018-01-04  100000.0
# 2018-01-05  100000.0
# 2018-01-08  100000.0
# ...              ...
# 2022-12-23   95169.0
# 2022-12-27   95169.0
# 2022-12-28   95169.0
# 2022-12-29   95169.0
# 2022-12-30   95169.0
#
# [1259 rows x 1 columns]

# %%
len(srr.orders_processed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 len(srr.orders_processed)
#
# NameError: name 'srr' is not defined

# %%
len(srr.orders_unprocessed)
